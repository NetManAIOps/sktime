# %% [markdown]
# ## Time Domain Features

# %% [markdown]
# ### Data and Time

# %%
# !pip3 install git+https://github.com/NetManAIOps/sktime.git
# Out:
# Collecting git+https://github.com/NetManAIOps/sktime.git
#   Cloning https://github.com/NetManAIOps/sktime.git to /private/var/folders/09/vy9lbtvd6532vkq3yfrht5w40000gn/T/pip-req-build-vw48pg47
#   Running command git clone --filter=blob:none --quiet https://github.com/NetManAIOps/sktime.git /private/var/folders/09/vy9lbtvd6532vkq3yfrht5w40000gn/T/pip-req-build-vw48pg47
#   Resolved https://github.com/NetManAIOps/sktime.git to commit 6f054389c025cddb36eb706d52ccc1eb8648b038
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib<1.6,>=1.2.0 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from sktime==0.40.1) (1.5.3)
# Requirement already satisfied: numpy<2.4,>=1.21 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from sktime==0.40.1) (2.3.5)
# Requirement already satisfied: packaging in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from sktime==0.40.1) (26.0)
# Requirement already satisfied: pandas<2.4.0,>=1.1 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from sktime==0.40.1) (2.3.3)
# Requirement already satisfied: scikit-base<0.14.0,>=0.6.1 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from sktime==0.40.1) (0.13.1)
# Requirement already satisfied: scikit-learn<1.8.0,>=0.24 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from sktime==0.40.1) (1.7.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from sktime==0.40.1) (1.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from pandas<2.4.0,>=1.1->sktime==0.40.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from pandas<2.4.0,>=1.1->sktime==0.40.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from pandas<2.4.0,>=1.1->sktime==0.40.1) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from scikit-learn<1.8.0,>=0.24->sktime==0.40.1) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/wannabtl/Documents/code/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=1.1->sktime==0.40.1) (1.17.0)
# Building wheels for collected packages: sktime
#   Building wheel for sktime (pyproject.toml) ... done
#   Created wheel for sktime: filename=sktime-0.40.1-py3-none-any.whl size=36379965 sha256=7b61c3979d2dd9c6a4fdec8d792a0f23f55481c830a86d937c5cdde95d338ded
#   Stored in directory: /private/var/folders/09/vy9lbtvd6532vkq3yfrht5w40000gn/T/pip-ephem-wheel-cache-fqz34rx8/wheels/3a/c3/66/e020f966230addc2f9ced53550a4a636cb9d50af204a9cdf0f
# Successfully built sktime
# Installing collected packages: sktime
#   Attempting uninstall: sktime
#     Found existing installation: sktime 0.40.1
#     Uninstalling sktime-0.40.1:
#       Successfully uninstalled sktime-0.40.1
# Successfully installed sktime-0.40.1
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate example time series data (simulating an upward trend with added noise)
np.random.seed(42)
time_steps = np.arange(8000)
original_series = np.log(time_steps + 1) + 0.1 * np.random.randn(8000)

# Create data at different time scales: monthly, daily, hourly
monthly_data = original_series[::720]
daily_data = original_series[::24]
hourly_data = original_series[::1]

fig, axs = plt.subplots(3, 1, figsize=(18, 15))

axs[0].plot(np.arange(len(monthly_data)), monthly_data, label='Monthly Data', color='blue')
axs[0].set_title('Monthly Data (Smoothed Trend)', fontsize=22)
axs[0].set_xlabel('Months', fontsize=18)
axs[0].set_ylabel('Values', fontsize=18)
axs[0].legend()
axs[0].grid(True)

axs[1].plot(np.arange(len(daily_data)), daily_data, label='Daily Data', color='green')
axs[1].set_title('Daily Data (More Detailed Trend)', fontsize=22)
axs[1].set_xlabel('Days', fontsize=18)
axs[1].set_ylabel('Values', fontsize=18)
axs[1].legend()
axs[1].grid(True)

axs[2].plot(np.arange(len(hourly_data)), hourly_data, label='Hourly Data', color='orange')
axs[2].set_title('Hourly Data (Most Detailed Trend)', fontsize=22)
axs[2].set_xlabel('Hours', fontsize=18)
axs[2].set_ylabel('Values', fontsize=18)
axs[2].legend()
axs[2].grid(True)

# plt.savefig('test.png', dpi=300)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Seasonal and Trend

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
time_steps = np.arange(300)

# Trend
trend = 0.02 * time_steps

# Seasonal: 2* 放大振幅，更长周期 (period=50)
seasonal = 2 * np.sin(2 * np.pi * time_steps / 50)

# Noise: 减小幅度，使 seasonal 更明显
noise = np.random.normal(0, 0.5, size=len(time_steps))

# Original Data = Trend + Seasonal + Noise
original_data = trend + seasonal + noise

# 统一 y 轴范围，便于看出成分对应关系
y_min = min(original_data.min(), trend.min(), seasonal.min(), noise.min())
y_max = max(original_data.max(), trend.max(), seasonal.max(), noise.max())
y_margin = (y_max - y_min) * 0.05
y_lim = (y_min - y_margin, y_max + y_margin)

# PPT 用图尺寸 (宽 8 英寸，高 2.5 英寸，适合放入幻灯片)
figsize_ppt = (8, 2.5)
save_dir = '/Users/wannabtl/Documents/code/lec3/figures/'

# 分别绘制并保存四张图
plots = [
    (original_data, 'Original Data', 'blue', 'original_data'),
    (trend, 'Trend', 'orange', 'trend'),
    (seasonal, 'Seasonal', 'green', 'seasonal'),
    (noise, 'Noise', 'red', 'noise'),
]

for data, title, color, filename in plots:
    fig, ax = plt.subplots(figsize=figsize_ppt)
    ax.plot(time_steps, data, label=title, color=color)
    ax.axhline(y=0, color='gray', linestyle='--', alpha=0.6)
    ax.set_ylim(y_lim)
    ax.set_title(title, fontsize=16)
    ax.legend(fontsize=12)
    ax.tick_params(labelsize=10)
    plt.tight_layout()
    fig.savefig(f'{save_dir}{filename}.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ### Autocorrelation

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf

np.random.seed(42)
time_steps = np.arange(0, 365 * 3)  
seasonal_data = np.sin(2 * np.pi * time_steps / 365) + 0.1 * np.random.randn(365 * 3)

seasonal_series = pd.Series(seasonal_data)

plt.figure(figsize=(10, 6))
plt.plot(time_steps, seasonal_data, label='Seasonal Data')
plt.title('Original Time Series Data', fontsize=20)
plt.xlabel('Time Steps (Days)')
plt.ylabel('Value')
# plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plot_acf(seasonal_series, lags=1000) 
plt.title('Autocorrelation of Time Series (Lags = 1000)', fontsize=15)
plt.show()

# %% [markdown]
# ### Stationarity

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

np.random.seed(42)
n = 50
non_stationary = np.cumsum(np.random.normal(0, 2, n))

plt.figure(figsize=(10, 6))
plt.plot(non_stationary, label='Non-Stationary')
plt.title('Non-Stationary Time Series', fontsize=20)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

adf_result = adfuller(non_stationary)
print("The P-Value:", adf_result[1])
# Out:
# The P-Value: 0.9685564849768947

# %%
stationary = np.random.normal(0, 1, 50)

plt.figure(figsize=(10, 6))
plt.plot(stationary, label='Stationary')
plt.title('Stationary Time Series', fontsize=20)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.legend()

plt.ylim(-10, 10)

plt.grid(True)
plt.show()



adf_result = adfuller(stationary)
print("The P-Value:", adf_result[1])
# Out:
# The P-Value: 3.188157037570127e-11

# %% [markdown]
# ### Differencing

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a synthetic time series with a clear trend and seasonality
np.random.seed(42)
time = np.arange(300)
trend = 0.5 * time  # Linear trend
seasonality = 10 * np.sin(2 * np.pi * time / 20)  # Sinusoidal seasonality
noise = np.random.normal(0, 1, 300)  # Random noise
time_series = trend + seasonality + noise

# Perform first-order differencing
differenced_series_1 = np.diff(time_series, n=1)

# Perform second-order differencing
differenced_series_2 = np.diff(differenced_series_1, n=1)

# Plot the original time series, first-order, and second-order differenced series
plt.figure(figsize=(12, 12))

# Original time series
plt.subplot(3, 1, 1)
plt.plot(time, time_series, label='Original Time Series', color='blue')
plt.title('Original Time Series', fontsize=20)
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()

# First-order differenced time series
plt.subplot(3, 1, 2)
plt.plot(time[1:], differenced_series_1, label='First-Order Differenced Series', color='orange')
plt.axhline(0, color='gray', linestyle='--', linewidth=0.8)
plt.title('First-Order Differenced Time Series', fontsize=20)
plt.xlabel('Time')
plt.ylabel('Differenced Value')
plt.ylim(-160, 160)
plt.legend()

# Second-order differenced time series
plt.subplot(3, 1, 3)
plt.plot(time[2:], differenced_series_2, label='Second-Order Differenced Series', color='green')
plt.axhline(0, color='gray', linestyle='--', linewidth=0.8)
plt.title('Second-Order Differenced Time Series')
plt.xlabel('Time')
plt.ylabel('Differenced Value')
plt.ylim(-160, 160)
plt.legend()

plt.tight_layout()
plt.show()
